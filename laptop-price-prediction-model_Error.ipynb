# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CSE422 Project/laptops_train.csv')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CSE422 Project/laptops_test.csv')

# %%
train.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price
# 0                      NaN  1.37kg  11912523.48
# 1                      NaN  1.34kg   7993374.48
# 2                      NaN  1.86kg   5112900.00
# 3                      NaN  1.83kg  22563005.40
# 4                      NaN  1.37kg  16037611.20

# %%
data = pd.concat([train,test])

# %%
print(train.shape,test.shape,data.shape)
# Out:
# (977, 13) (325, 13) (1302, 13)

# %% [markdown]
# <center><h3> Data Preprocessing </h3></center>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1302 non-null   object
#  1   Model Name                1302 non-null   object
#  2   Category                  1302 non-null   object
#  3   Screen Size               1302 non-null   object
#  4   Screen                    1302 non-null   object
#  5   CPU                       1302 non-null   object
#  6   RAM                       1302 non-null   object
#  7    Storage                  1302 non-null   object
#  8   GPU                       1302 non-null   object
#  9   Operating System          1302 non-null   object
#  10  Operating System Version  1132 non-null   object
#  11  Weight                    1302 non-null   object
#  12  Price                     1302 non-null   float64
# dtypes: float64(1), object(12)
# memory usage: 142.4+ KB

# %%
data.describe()
# Out:
#               Price
# count  1.302000e+03
# mean   9.987213e+06
# std    6.215746e+06
# min    1.547208e+06
# 25%    5.326308e+06
# 50%    8.687484e+06
# 75%    1.321198e+07
# max    5.423231e+07

# %%
plt.figure(figsize=(10,5))
plt.hist(data["Price"])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.hist(data["RAM"])
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.hist(data["Weight"])
plt.show()

# %%
data.isnull().sum()
# Out:
# Manufacturer                  0
# Model Name                    0
# Category                      0
# Screen Size                   0
# Screen                        0
# CPU                           0
# RAM                           0
#  Storage                      0
# GPU                           0
# Operating System              0
# Operating System Version    170
# Weight                        0
# Price                         0
# dtype: int64

# %%
data = data.drop('Operating System Version',axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 324
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1302 non-null   object
#  1   Model Name        1302 non-null   object
#  2   Category          1302 non-null   object
#  3   Screen Size       1302 non-null   object
#  4   Screen            1302 non-null   object
#  5   CPU               1302 non-null   object
#  6   RAM               1302 non-null   object
#  7    Storage          1302 non-null   object
#  8   GPU               1302 non-null   object
#  9   Operating System  1302 non-null   object
#  10  Weight            1302 non-null   object
#  11  Price             1302 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 132.2+ KB

# %%
data = data.rename(columns={' Storage':'Storage'})

# %%
data.isnull().sum()
# Out:
# Manufacturer        0
# Model Name          0
# Category            0
# Screen Size         0
# Screen              0
# CPU                 0
# RAM                 0
# Storage             0
# GPU                 0
# Operating System    0
# Weight              0
# Price               0
# dtype: int64

# %%
data.sample(50)
# Out:
#     Manufacturer                             Model Name            Category  \
# 252         Asus  X505BP-BR019T (A9-9420/4GB/1TB/Radeon            Notebook
# 44          Dell                          Inspiron 7773  2 in 1 Convertible
# 521           HP                           Spectre X360           Ultrabook
# 135           HP                            Probook 440            Notebook
# 248         Dell                                 XPS 13           Ultrabook
# 20          Asus                       Rog GL553VE-DS74              Gaming
# 886         Dell                            Vostro 3568            Notebook
# 794        Apple                            MacBook 12"           Ultrabook
# 18        Lenovo                      IdeaPad 320-15IKB            Notebook
# 194         Dell                          Inspiron 5379  2 in 1 Convertible
# 48          Dell                          Inspiron 3567            Notebook
# 378         Asus                        VivoBook E403NA            Notebook
# 312          MSI                             GE63VR 7RF              Gaming
# 491      Toshiba                      Portege X30-D-10L           Ultrabook
# 774           HP                          EliteBook 820           Ultrabook
# 517         Asus                           ROG Zephyrus              Gaming
# 940           HP                         Omen 17-W006na              Gaming
# 594       Lenovo  V320-17ISK (i3-6006U/4GB/500GB/FHD/No            Notebook
# 371         Acer                               Aspire 3            Notebook
# 186         Dell                                 XPS 15            Notebook
# 154           HP                          EliteBook 840           Ultrabook
# 162         Dell                          Inspiron 3576            Notebook
# 772      Toshiba                        Tecra A40-C-1E5            Notebook
# 500         Asus                        VivoBook E201NA             Netbook
# 16          Dell                          Inspiron 3567            Notebook
# 157       Lenovo                      IdeaPad 500-15ISK            Notebook
# 404          MSI                             GE73VR 7RF              Gaming
# 846           HP                        Chromebook X360  2 in 1 Convertible
# 819         Dell                          Latitude 3480            Notebook
# 233         Asus       FX502VM-AS73 (i7-7700HQ/16GB/1TB            Notebook
# 205       Lenovo                     Legion Y520-15IKBN              Gaming
# 191          MSI                               PL60 7RD              Gaming
# 552         Dell                           Alienware 17              Gaming
# 99           MSI                       GT72VR Dominator              Gaming
# 255         Dell                            Vostro 5370           Ultrabook
# 71          Dell                          Inspiron 5370           Ultrabook
# 400       Lenovo                      IdeaPad 320-15IAP            Notebook
# 388         Dell                         Precision 5520         Workstation
# 261       Lenovo                            ThinkPad 13            Notebook
# 680          MSI                              GV62M 7RD              Gaming
# 115         Dell                          Inspiron 5370           Ultrabook
# 23            HP                                 ENVY -            Notebook
# 608       Lenovo                         Yoga 720-15IKB  2 in 1 Convertible
# 675          MSI                              GP62 7RDX              Gaming
# 363           HP                                 250 G6            Notebook
# 23          Dell                          Inspiron 5379  2 in 1 Convertible
# 498       Lenovo                            ThinkPad 13            Notebook
# 768      Samsung                             Notebook 9           Ultrabook
# 131         Dell                          Inspiron 3567            Notebook
# 289       Lenovo                      IdeaPad 320-15IKB            Notebook
#
#     Screen Size                                     Screen  \
# 252       15.6"                                   1366x768
# 44        17.3"            Full HD / Touchscreen 1920x1080
# 521       13.3"                IPS Panel Full HD 1920x1080
# 135       14.0"                          Full HD 1920x1080
# 248       13.3"           Quad HD+ / Touchscreen 3200x1800
# 20        15.6"                          Full HD 1920x1080
# 886       15.6"                                   1366x768
# 794       12.0"         IPS Panel Retina Display 2304x1440
# 18        15.6"                          Full HD 1920x1080
# 194       13.3"  IPS Panel Full HD / Touchscreen 1920x1080
# 48        15.6"                          Full HD 1920x1080
# 378       14.0"                                   1366x768
# 312       15.6"                IPS Panel Full HD 1920x1080
# 491       13.3"            Full HD / Touchscreen 1920x1080
# 774       12.5"                                   1366x768
# 517       15.6"                          Full HD 1920x1080
# 940       17.3"                IPS Panel Full HD 1920x1080
# 594       17.3"                          Full HD 1920x1080
# 371       15.6"                                   1366x768
# 186       15.6"        4K Ultra HD / Touchscreen 3840x2160
# 154       14.0"                          Full HD 1920x1080
# 162       15.6"                          Full HD 1920x1080
# 772       14.0"                         IPS Panel 1366x768
# 500       11.6"                                   1366x768
# 16        15.6"                          Full HD 1920x1080
# 157       15.6"                          Full HD 1920x1080
# 404       17.3"                          Full HD 1920x1080
# 846       11.6"                       Touchscreen 1366x768
# 819       14.0"                                   1366x768
# 233       15.6"                          Full HD 1920x1080
# 205       15.6"                          Full HD 1920x1080
# 191       15.6"                IPS Panel Full HD 1920x1080
# 552       17.3"                IPS Panel Full HD 1920x1080
# 99        17.3"                          Full HD 1920x1080
# 255       13.3"                          Full HD 1920x1080
# 71        13.3"                IPS Panel Full HD 1920x1080
# 400       15.6"                                   1366x768
# 388       15.6"                IPS Panel Full HD 1920x1080
# 261       13.3"                IPS Panel Full HD 1920x1080
# 680       15.6"                          Full HD 1920x1080
# 115       13.3"                IPS Panel Full HD 1920x1080
# 23        13.3"                IPS Panel Full HD 1920x1080
# 608       15.6"  IPS Panel Full HD / Touchscreen 1920x1080
# 675       15.6"                          Full HD 1920x1080
# 363       15.6"                          Full HD 1920x1080
# 23        13.3"            Full HD / Touchscreen 1920x1080
# 498       13.3"                IPS Panel Full HD 1920x1080
# 768       13.3"            Full HD / Touchscreen 1920x1080
# 131       15.6"                          Full HD 1920x1080
# 289       15.6"                          Full HD 1920x1080
#
#                                       CPU   RAM               Storage  \
# 252               AMD A9-Series 9420 3GHz   4GB               1TB HDD
# 44             Intel Core i5 8250U 1.6GHz  12GB               1TB HDD
# 521            Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 135            Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
# 248            Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 20            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 886            Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 794                   Intel Core M 1.2GHz   8GB   512GB Flash Storage
# 18             Intel Core i3 7100U 2.4GHz   8GB               1TB HDD
# 194            Intel Core i7 8550U 1.8GHz   8GB               1TB HDD
# 48             Intel Core i5 7200U 2.5GHz   4GB             256GB SSD
# 378  Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 312           Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 491            Intel Core i7 7500U 2.7GHz  32GB             512GB SSD
# 774            Intel Core i5 6200U 2.3GHz   4GB             256GB SSD
# 517           Intel Core i7 7700HQ 2.8GHz  24GB             512GB SSD
# 940           Intel Core i5 6300HQ 2.3GHz   8GB  128GB SSD +  1TB HDD
# 594              Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 371               AMD A9-Series 9420 3GHz   4GB             128GB SSD
# 186           Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 154            Intel Core i5 7500U 2.7GHz   4GB             256GB SSD
# 162            Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 772            Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 500  Intel Celeron Dual Core N3350 1.1GHz   4GB    64GB Flash Storage
# 16             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 157            Intel Core i7 6500U 2.5GHz  16GB            1TB Hybrid
# 404           Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 846  Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 819            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 233           Intel Core i7 7700HQ 2.8GHz  16GB  128GB SSD +  1TB HDD
# 205           Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 191            Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 552           Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 99            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 255            Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 71             Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
# 400  Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 388           Intel Core i7 6820HQ 2.7GHz   8GB             256GB SSD
# 261            Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
# 680           Intel Core i5 7300HQ 2.5GHz   8GB             256GB SSD
# 115            Intel Core i5 8250U 1.6GHz   4GB             256GB SSD
# 23             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 608           Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 675           Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 363            Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 23             Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 498            Intel Core i3 7100U 2.4GHz   8GB             256GB SSD
# 768            Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 131              Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 289            Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
#
#                             GPU Operating System   Weight        Price
# 252          AMD Radeon R5 M420          Windows   1.68kg   4170348.00
# 44         Nvidia GeForce 150MX          Windows   2.77kg   8883108.00
# 521       Intel HD Graphics 620          Windows   1.32kg  12439908.00
# 135      Intel UHD Graphics 620          Windows   1.63kg   8785296.00
# 248       Intel HD Graphics 620          Windows   1.29kg  13133484.00
# 20   Nvidia GeForce GTX 1050 Ti          Windows    2.5kg  15996708.00
# 886         AMD Radeon R5 M420X            Linux   2.18kg   4052084.40
# 794      Intel HD Graphics 5300           Mac OS  0.920kg  10359180.00
# 18         Nvidia GeForce 940MX            No OS    2.2kg   4437108.00
# 194      Intel UHD Graphics 620          Windows   1.62kg   7460388.00
# 48           AMD Radeon R5 M430          Windows    2.3kg   5681988.00
# 378       Intel HD Graphics 500          Windows    1.5kg   2543112.00
# 312     Nvidia GeForce GTX 1070          Windows    2.8kg  18664308.00
# 491       Intel HD Graphics 620          Windows   1.05kg  24888708.00
# 774       Intel HD Graphics 520          Windows   1.26kg  11061648.00
# 517      Nvidia GeForce GTX1080          Windows   2.24kg  26391456.00
# 940     Nvidia GeForce GTX 965M          Windows   2.75kg  12439908.00
# 594       Intel HD Graphics 520            No OS    2.8kg   4703868.00
# 371               AMD Radeon R5          Windows    2.1kg   3787992.00
# 186     Nvidia GeForce GTX 1050          Windows   2.06kg  21314124.00
# 154       Intel HD Graphics 620          Windows   1.48kg   9621144.00
# 162              AMD Radeon 520          Windows   2.13kg   6473376.00
# 772       Intel HD Graphics 520          Windows   1.75kg   9069840.00
# 500       Intel HD Graphics 500          Windows    1.2kg   3023280.00
# 16           AMD Radeon R5 M430          Windows    2.2kg   6624540.00
# 157          AMD Radeon R7 M360          Windows    2.5kg   9772308.00
# 404     Nvidia GeForce GTX 1070          Windows    2.8kg  19998108.00
# 846       Intel HD Graphics 500        Chrome OS    1.4kg   5468580.00
# 819       Intel HD Graphics 520          Windows   1.76kg   6713460.00
# 233     Nvidia GeForce GTX 1060          Windows    2.2kg  15552108.00
# 205     Nvidia GeForce GTX 1060            No OS    2.4kg  12431016.00
# 191     Nvidia GeForce GTX 1050          Windows    2.2kg   7460388.00
# 552     Nvidia GeForce GTX 1070          Windows   4.42kg  23999508.00
# 99      Nvidia GeForce GTX 1070          Windows   3.78kg  22221108.00
# 255      Intel UHD Graphics 620          Windows   1.41kg   8438508.00
# 71               AMD Radeon 530          Windows    1.4kg   8491860.00
# 400       Intel HD Graphics 500          Windows    2.2kg   2720952.00
# 388         Nvidia Quadro M1200          Windows      2kg  18984420.00
# 261       Intel HD Graphics 620          Windows    1.4kg  13329108.00
# 680     Nvidia GeForce GTX 1050          Windows    2.2kg   8873326.80
# 115              AMD Radeon 530          Windows    1.4kg   7276768.20
# 23        Intel HD Graphics 620          Windows   1.34kg  10572588.00
# 608       Intel HD Graphics 630          Windows      2kg  11550708.00
# 675     Nvidia GeForce GTX 1050          Windows    2.4kg  11506248.00
# 363       Intel HD Graphics 620          Windows   1.86kg   5681988.00
# 23       Intel UHD Graphics 620          Windows   1.62kg   7282548.00
# 498       Intel HD Graphics 620          Windows    1.4kg   8438508.00
# 768       Intel HD Graphics 620          Windows   1.31kg  14218308.00
# 131          AMD Radeon R5 M430          Windows    2.2kg   3992508.00
# 289        Nvidia GeForce 940MX            No OS    2.2kg   5859916.92

# %%
data['Wt'] = data['Weight'].apply(lambda x: x.split('k')[0])
data['R'] = data['RAM'].apply(lambda x: x.split('G')[0])
data['SS'] = data['Screen Size'].apply(lambda x: x.split('\"')[0])

# %%
data.head(20)
# Out:
#    Manufacturer         Model Name   Category Screen Size  \
# 0         Apple        MacBook Pro  Ultrabook       13.3"
# 1         Apple        Macbook Air  Ultrabook       13.3"
# 2            HP             250 G6   Notebook       15.6"
# 3         Apple        MacBook Pro  Ultrabook       15.4"
# 4         Apple        MacBook Pro  Ultrabook       13.3"
# 5          Acer           Aspire 3   Notebook       15.6"
# 6         Apple        MacBook Pro  Ultrabook       15.4"
# 7         Apple        Macbook Air  Ultrabook       13.3"
# 8          Asus    ZenBook UX430UN  Ultrabook       14.0"
# 9          Acer            Swift 3  Ultrabook       14.0"
# 10           HP             250 G6   Notebook       15.6"
# 11           HP             250 G6   Notebook       15.6"
# 12        Apple        MacBook Pro  Ultrabook       15.4"
# 13         Dell      Inspiron 3567   Notebook       15.6"
# 14        Apple        MacBook 12"  Ultrabook       12.0"
# 15        Apple        MacBook Pro  Ultrabook       13.3"
# 16         Dell      Inspiron 3567   Notebook       15.6"
# 17        Apple        MacBook Pro  Ultrabook       15.4"
# 18       Lenovo  IdeaPad 320-15IKB   Notebook       15.6"
# 19         Dell             XPS 13  Ultrabook       13.3"
#
#                                        Screen                         CPU  \
# 0          IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1                                    1440x900        Intel Core i5 1.8GHz
# 2                           Full HD 1920x1080  Intel Core i5 7200U 2.5GHz
# 3          IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz
# 4          IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz
# 5                                    1366x768     AMD A9-Series 9420 3GHz
# 6          IPS Panel Retina Display 2880x1800        Intel Core i7 2.2GHz
# 7                                    1440x900        Intel Core i5 1.8GHz
# 8                           Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
# 9                 IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 10                                   1366x768  Intel Core i5 7200U 2.5GHz
# 11                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 12         IPS Panel Retina Display 2880x1800        Intel Core i7 2.8GHz
# 13                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 14         IPS Panel Retina Display 2304x1440      Intel Core M m3 1.2GHz
# 15         IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 16                          Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 17         IPS Panel Retina Display 2880x1800        Intel Core i7 2.9GHz
# 18                          Full HD 1920x1080  Intel Core i3 7100U 2.4GHz
# 19  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
#
#      RAM              Storage                           GPU Operating System  \
# 0    8GB            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1    8GB  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2    8GB            256GB SSD         Intel HD Graphics 620            No OS
# 3   16GB            512GB SSD            AMD Radeon Pro 455            macOS
# 4    8GB            256GB SSD  Intel Iris Plus Graphics 650            macOS
# 5    4GB            500GB HDD                 AMD Radeon R5          Windows
# 6   16GB  256GB Flash Storage       Intel Iris Pro Graphics           Mac OS
# 7    8GB  256GB Flash Storage        Intel HD Graphics 6000            macOS
# 8   16GB            512GB SSD          Nvidia GeForce MX150          Windows
# 9    8GB            256GB SSD        Intel UHD Graphics 620          Windows
# 10   4GB            500GB HDD         Intel HD Graphics 620            No OS
# 11   4GB            500GB HDD         Intel HD Graphics 520            No OS
# 12  16GB            256GB SSD            AMD Radeon Pro 555            macOS
# 13   4GB            256GB SSD            AMD Radeon R5 M430          Windows
# 14   8GB            256GB SSD         Intel HD Graphics 615            macOS
# 15   8GB            256GB SSD  Intel Iris Plus Graphics 640            macOS
# 16   8GB            256GB SSD            AMD Radeon R5 M430          Windows
# 17  16GB            512GB SSD            AMD Radeon Pro 560            macOS
# 18   8GB              1TB HDD          Nvidia GeForce 940MX            No OS
# 19   8GB            128GB SSD        Intel UHD Graphics 620          Windows
#
#     Weight        Price    Wt   R    SS
# 0   1.37kg  11912523.48  1.37   8  13.3
# 1   1.34kg   7993374.48  1.34   8  13.3
# 2   1.86kg   5112900.00  1.86   8  15.6
# 3   1.83kg  22563005.40  1.83  16  15.4
# 4   1.37kg  16037611.20  1.37   8  13.3
# 5    2.1kg   3556800.00   2.1   4  15.6
# 6   2.04kg  19028613.24  2.04  16  15.4
# 7   1.34kg  10303160.40  1.34   8  13.3
# 8    1.3kg  13293540.00   1.3  16  14.0
# 9    1.6kg   6846840.00   1.6   8  14.0
# 10  1.86kg   3502558.80  1.86   4  15.6
# 11  1.86kg   3067651.08  1.86   4  15.6
# 12  1.83kg  21696213.24  1.83  16  15.4
# 13   2.2kg   4436218.80   2.2   4  15.6
# 14  0.92kg  11225260.80  0.92   8  12.0
# 15  1.37kg  13502946.60  1.37   8  13.3
# 16   2.2kg   6624540.00   2.2   8  15.6
# 17  1.83kg  25413336.00  1.83  16  15.4
# 18   2.2kg   4437108.00   2.2   8  15.6
# 19  1.22kg   8705268.00  1.22   8  13.3

# %%
data = data.drop(['Weight','Screen Size','RAM'],axis=1)
data = data.rename(columns={'SS':'Screen Size'})
data = data.rename(columns={'R':'RAM'})
data = data.rename(columns={'Wt':'Weight'})
data.head()
# Out:
#   Manufacturer   Model Name   Category                              Screen  \
# 0        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
# 1        Apple  Macbook Air  Ultrabook                            1440x900
# 2           HP       250 G6   Notebook                   Full HD 1920x1080
# 3        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2880x1800
# 4        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           CPU              Storage  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             GPU Operating System        Price Weight RAM  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48   1.37   8
# 1        Intel HD Graphics 6000            macOS   7993374.48   1.34   8
# 2         Intel HD Graphics 620            No OS   5112900.00   1.86   8
# 3            AMD Radeon Pro 455            macOS  22563005.40   1.83  16
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20   1.37   8
#
#   Screen Size
# 0        13.3
# 1        13.3
# 2        15.6
# 3        15.4
# 4        13.3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 324
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1302 non-null   object
#  1   Model Name        1302 non-null   object
#  2   Category          1302 non-null   object
#  3   Screen            1302 non-null   object
#  4   CPU               1302 non-null   object
#  5   Storage           1302 non-null   object
#  6   GPU               1302 non-null   object
#  7   Operating System  1302 non-null   object
#  8   Price             1302 non-null   float64
#  9   Weight            1302 non-null   object
#  10  RAM               1302 non-null   object
#  11  Screen Size       1302 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 132.2+ KB

# %%
data['RAM'] = data['RAM'].astype('int64')
data['Screen Size'] = data['Screen Size'].astype('float64')
data['Weight'] = data['Weight'].astype('float64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 324
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1302 non-null   object
#  1   Model Name        1302 non-null   object
#  2   Category          1302 non-null   object
#  3   Screen            1302 non-null   object
#  4   CPU               1302 non-null   object
#  5   Storage           1302 non-null   object
#  6   GPU               1302 non-null   object
#  7   Operating System  1302 non-null   object
#  8   Price             1302 non-null   float64
#  9   Weight            1302 non-null   float64
#  10  RAM               1302 non-null   int64
#  11  Screen Size       1302 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 132.2+ KB

# %%
plt.figure(figsize=(15,8))
sns.histplot(data['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
plt.figure(figsize=(15,8))
sns.displot(data['Price'])

# %%
plt.figure(figsize=(15,8))
data['Manufacturer'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = data['Manufacturer'], y = data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(10,5))
data['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = data['Category'], y = data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(10,5))
data['Screen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
data['TouchScreen'] = data['Screen'].apply(lambda x: 1 if 'Touchscreen' in x else 0)
data.sample(20)
# Out:
#     Manufacturer                            Model Name            Category  \
# 445         Dell                         Latitude 5480            Notebook
# 711         Dell                         Latitude 5480            Notebook
# 887         Asus                    Rog GL753VD-GC082T              Gaming
# 237         Asus      X555QG-DM242T (A10-9620P/4GB/1TB            Notebook
# 769         Acer                        Aspire A315-31            Notebook
# 437       Google                       Pixelbook (Core           Ultrabook
# 817           HP                         Chromebook 11             Netbook
# 305       Lenovo                     IdeaPad 320-15IAP            Notebook
# 861           HP                         EliteBook 850            Notebook
# 223       Lenovo                     IdeaPad 310-15ISK            Notebook
# 394         Dell                         Inspiron 5567            Notebook
# 203       Lenovo                     Legion Y720-15IKB              Gaming
# 619         Acer  CB5-132T-C9KK (N3160/4GB/32GB/Chrome  2 in 1 Convertible
# 504       Lenovo                        Chromebook N23             Netbook
# 110           HP                         Chromebook 13            Notebook
# 415         Dell                         Inspiron 3567            Notebook
# 204         Dell                        Precision 7520         Workstation
# 547       Lenovo   V310-15ISK (i5-6200U/4GB/1TB/FHD/No            Notebook
# 150         Dell                         Inspiron 5577              Gaming
# 314         Dell                         Inspiron 3552            Notebook
#
#                              Screen                                   CPU  \
# 445               Full HD 1920x1080           Intel Core i5 7440HQ 2.8GHz
# 711               Full HD 1920x1080           Intel Core i5 7440HQ 2.8GHz
# 887               Full HD 1920x1080           Intel Core i5 7300HQ 2.5GHz
# 237               Full HD 1920x1080       AMD A10-Series A10-9620P 2.5GHz
# 769                        1366x768  Intel Pentium Quad Core N4200 1.1GHz
# 437           Touchscreen 2400x1600             Intel Core i7 7Y75 1.3GHz
# 817                        1366x768  Intel Celeron Dual Core N3060 1.6GHz
# 305                        1366x768  Intel Pentium Quad Core N4200 1.1GHz
# 861               Full HD 1920x1080            Intel Core i5 7300U 2.6GHz
# 223                        1366x768            Intel Core i7 6500U 2.5GHz
# 394               Full HD 1920x1080            Intel Core i7 7500U 2.7GHz
# 203     IPS Panel Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz
# 619  IPS Panel Touchscreen 1366x768  Intel Celeron Quad Core N3160 1.6GHz
# 504                        1366x768  Intel Celeron Dual Core N3060 1.6GHz
# 110              Quad HD+ 3200x1800  Intel Pentium Dual Core 4405Y 1.5GHz
# 415               Full HD 1920x1080            Intel Core i5 7200U 2.5GHz
# 204           4K Ultra HD 3840x2160           Intel Xeon E3-1505M V6 3GHz
# 547               Full HD 1920x1080            Intel Core i5 6200U 2.3GHz
# 150               Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz
# 314                        1366x768  Intel Celeron Dual Core N3050 1.6GHz
#
#                   Storage                      GPU Operating System  \
# 445             256GB SSD     Nvidia GeForce 930MX          Windows
# 711             256GB SSD     Nvidia GeForce 930MX            Linux
# 887  128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050          Windows
# 237  128GB SSD +  1TB HDD       AMD Radeon R5 M430          Windows
# 769               1TB HDD    Intel HD Graphics 505            Linux
# 437             512GB SSD    Intel HD Graphics 615        Chrome OS
# 817    16GB Flash Storage    Intel HD Graphics 400        Chrome OS
# 305               1TB HDD    Intel HD Graphics 505            No OS
# 861             256GB SSD       AMD Radeon R7 M465          Windows
# 223             500GB HDD     Nvidia GeForce 920MX            No OS
# 394             256GB SSD       AMD Radeon R7 M445            Linux
# 203  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1060          Windows
# 619    32GB Flash Storage    Intel HD Graphics 400        Chrome OS
# 504              16GB SSD    Intel HD Graphics 400        Chrome OS
# 110    32GB Flash Storage    Intel HD Graphics 515        Chrome OS
# 415             256GB SSD       AMD Radeon R5 M430            Linux
# 204  256GB SSD +  1TB HDD      Nvidia Quadro M1200          Windows
# 547               1TB HDD    Intel HD Graphics 520            No OS
# 150             512GB SSD  Nvidia GeForce GTX 1050          Windows
# 314             500GB HDD        Intel HD Graphics          Windows
#
#            Price  Weight  RAM  Screen Size  TouchScreen
# 445  10483668.00    1.64    8         14.0            0
# 711   9683388.00    1.64    8         14.0            0
# 887  12181150.80    2.20   12         17.3            0
# 237   5112900.00    2.20    4         15.6            0
# 769   2649816.00    2.10    4         15.6            0
# 437  19553508.00    1.10   16         12.3            1
# 817   3423420.00    1.23    4         11.6            0
# 305   3201031.08    2.20    4         15.6            0
# 861  11995308.00    1.84    8         15.6            0
# 223   5593068.00    2.20    8         15.6            0
# 394   6925712.04    2.33    8         15.6            0
# 203  15552108.00    3.20   16         15.6            0
# 619   3370068.00    1.25    4         11.6            1
# 504   2356380.00    1.25    4         11.6            0
# 110   5468580.00    1.29    4         13.3            0
# 415   5325418.80    2.30    4         15.6            0
# 204  27165060.00    2.80   16         15.6            0
# 547   4111216.20    2.15    4         15.6            0
# 150  11108419.92    2.56   16         15.6            0
# 314   3370068.00    2.20    2         15.6            0

# %%
sns.barplot(x = data['TouchScreen'], y = data['Price'])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
data['Ips'] = data['Screen'].apply(lambda x: 1 if 'IPS' in x else 0)
data.sample(5)
# Out:
#     Manufacturer                             Model Name  Category  \
# 270       Lenovo  V510-15IKB (i5-7200U/8GB/256GB/FHD/No  Notebook
# 797         Dell                          Latitude 3580  Notebook
# 149         Acer                         Aspire A315-51  Notebook
# 123           HP                            Probook 470  Notebook
# 611         Dell                          Inspiron 7559    Gaming
#
#                           Screen                          CPU    Storage  \
# 270  IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz  256GB SSD
# 797                     1366x768   Intel Core i5 7200U 2.5GHz  128GB SSD
# 149                     1366x768     Intel Core i3 6006U 2GHz    1TB HDD
# 123            Full HD 1920x1080   Intel Core i7 8550U 1.8GHz  512GB SSD
# 611            Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz    1TB HDD
#
#                                 GPU Operating System        Price  Weight  \
# 270           Intel HD Graphics 620            No OS   5095116.00    2.30
# 797           Intel HD Graphics 620          Windows   7202520.00    1.95
# 149           Intel HD Graphics 520          Windows   3974724.00    2.10
# 123           Nvidia GeForce 930MX           Windows  11301732.00    2.50
# 611  Nvidia GeForce GTX 960<U+039C>          Windows   7816156.92    2.59
#
#      RAM  Screen Size  TouchScreen  Ips
# 270    8         15.6            0    1
# 797    8         15.6            0    0
# 149    4         15.6            0    0
# 123   16         17.3            0    0
# 611   16         15.6            0    0

# %%
sns.barplot(x = data['Ips'], y = data['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = data['Screen'].str.split('x',n=1,expand=True)
data.sample(5)
# Out:
#     Manufacturer           Model Name  Category                       Screen  \
# 460         Acer       Aspire E5-576G  Notebook            Full HD 1920x1080
# 187       Lenovo   Legion Y520-15IKBN    Gaming  IPS Panel Full HD 1920x1080
# 166         Acer             Aspire 3  Notebook                     1366x768
# 206         Dell        Inspiron 3567  Notebook         Touchscreen 1366x768
# 962         Acer  Aspire F5-573G-510L  Notebook            Full HD 1920x1080
#
#                                       CPU               Storage  \
# 460              Intel Core i3 6006U 2GHz               1TB HDD
# 187           Intel Core i5 7300HQ 2.5GHz             256GB SSD
# 166  Intel Pentium Quad Core N4200 1.1GHz               1TB HDD
# 206            Intel Core i3 7100U 2.4GHz               1TB HDD
# 962            Intel Core i5 7200U 2.5GHz  128GB SSD +  1TB HDD
#
#                          GPU Operating System       Price  Weight  RAM  \
# 460     Nvidia GeForce 940MX          Windows  4837248.00    2.23    4
# 187  Nvidia GeForce GTX 1050            No OS  6926868.00    2.40    8
# 166    Intel HD Graphics 505          Windows  3232330.92    2.10    4
# 206    Intel HD Graphics 620          Windows  3903588.00    2.30    6
# 962  Nvidia GeForce GTX 950M          Windows  8972028.00    2.40   12
#
#      Screen Size  TouchScreen  Ips
# 460         15.6            0    0
# 187         15.6            0    1
# 166         15.6            0    0
# 206         15.6            1    0
# 962         15.6            0    0

# %%
data['X_reso'] = new[0]
data['Y_reso'] = new[1]
data.head()
# Out:
#   Manufacturer   Model Name   Category                              Screen  \
# 0        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
# 1        Apple  Macbook Air  Ultrabook                            1440x900
# 2           HP       250 G6   Notebook                   Full HD 1920x1080
# 3        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2880x1800
# 4        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           CPU              Storage  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             GPU Operating System        Price  Weight  RAM  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48    1.37    8
# 1        Intel HD Graphics 6000            macOS   7993374.48    1.34    8
# 2         Intel HD Graphics 620            No OS   5112900.00    1.86    8
# 3            AMD Radeon Pro 455            macOS  22563005.40    1.83   16
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20    1.37    8
#
#    Screen Size  TouchScreen  Ips                         X_reso Y_reso
# 0         13.3            0    1  IPS Panel Retina Display 2560   1600
# 1         13.3            0    0                           1440    900
# 2         15.6            0    0                   Full HD 1920   1080
# 3         15.4            0    1  IPS Panel Retina Display 2880   1800
# 4         13.3            0    1  IPS Panel Retina Display 2560   1600

# %%
data['X_reso'] = data['X_reso'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
data.head()
# Out:
#   Manufacturer   Model Name   Category                              Screen  \
# 0        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
# 1        Apple  Macbook Air  Ultrabook                            1440x900
# 2           HP       250 G6   Notebook                   Full HD 1920x1080
# 3        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2880x1800
# 4        Apple  MacBook Pro  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           CPU              Storage  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             GPU Operating System        Price  Weight  RAM  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48    1.37    8
# 1        Intel HD Graphics 6000            macOS   7993374.48    1.34    8
# 2         Intel HD Graphics 620            No OS   5112900.00    1.86    8
# 3            AMD Radeon Pro 455            macOS  22563005.40    1.83   16
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20    1.37    8
#
#    Screen Size  TouchScreen  Ips X_reso Y_reso
# 0         13.3            0    1   2560   1600
# 1         13.3            0    0   1440    900
# 2         15.6            0    0   1920   1080
# 3         15.4            0    1   2880   1800
# 4         13.3            0    1   2560   1600

# %%
data['X_reso'] = data['X_reso'].astype('int64')
data['Y_reso'] = data['Y_reso'].astype('int64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 324
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1302 non-null   object
#  1   Model Name        1302 non-null   object
#  2   Category          1302 non-null   object
#  3   Screen            1302 non-null   object
#  4   CPU               1302 non-null   object
#  5   Storage           1302 non-null   object
#  6   GPU               1302 non-null   object
#  7   Operating System  1302 non-null   object
#  8   Price             1302 non-null   float64
#  9   Weight            1302 non-null   float64
#  10  RAM               1302 non-null   int64
#  11  Screen Size       1302 non-null   float64
#  12  TouchScreen       1302 non-null   int64
#  13  Ips               1302 non-null   int64
#  14  X_reso            1302 non-null   int64
#  15  Y_reso            1302 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 172.9+ KB

# %%
data.corr()['Price']
# Out:
# <ipython-input-578-6b59db53f049>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()['Price']
# Price          1.000000
# Weight         0.210166
# RAM            0.742802
# Screen Size    0.067922
# TouchScreen    0.189931
# Ips            0.252799
# X_reso         0.557129
# Y_reso         0.553289
# Name: Price, dtype: float64

# %% [markdown]
# Finding PPI(Pixels Per square Inch)<br>
# Formula:<br>
# PPI = ((x_reso^2 + y_reso^2)^1/2)/inches

# %%
data['ppi'] = (((data['X_reso']**2 + data['Y_reso']**2)**0.5)/data['Screen Size']).astype('float64')

# %%
data['resolution'] = data['X_reso'] * data['Y_reso']

# %%
data.corr()['Price']
# Out:
# <ipython-input-581-6b59db53f049>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()['Price']
# Price          1.000000
# Weight         0.210166
# RAM            0.742802
# Screen Size    0.067922
# TouchScreen    0.189931
# Ips            0.252799
# X_reso         0.557129
# Y_reso         0.553289
# ppi            0.473125
# resolution     0.516261
# Name: Price, dtype: float64

# %%
data = data.drop(['X_reso','Y_reso','Screen Size','Screen'],axis=1)
data.head(20)
# Out:
#    Manufacturer         Model Name   Category                         CPU  \
# 0         Apple        MacBook Pro  Ultrabook        Intel Core i5 2.3GHz
# 1         Apple        Macbook Air  Ultrabook        Intel Core i5 1.8GHz
# 2            HP             250 G6   Notebook  Intel Core i5 7200U 2.5GHz
# 3         Apple        MacBook Pro  Ultrabook        Intel Core i7 2.7GHz
# 4         Apple        MacBook Pro  Ultrabook        Intel Core i5 3.1GHz
# 5          Acer           Aspire 3   Notebook     AMD A9-Series 9420 3GHz
# 6         Apple        MacBook Pro  Ultrabook        Intel Core i7 2.2GHz
# 7         Apple        Macbook Air  Ultrabook        Intel Core i5 1.8GHz
# 8          Asus    ZenBook UX430UN  Ultrabook  Intel Core i7 8550U 1.8GHz
# 9          Acer            Swift 3  Ultrabook  Intel Core i5 8250U 1.6GHz
# 10           HP             250 G6   Notebook  Intel Core i5 7200U 2.5GHz
# 11           HP             250 G6   Notebook    Intel Core i3 6006U 2GHz
# 12        Apple        MacBook Pro  Ultrabook        Intel Core i7 2.8GHz
# 13         Dell      Inspiron 3567   Notebook    Intel Core i3 6006U 2GHz
# 14        Apple        MacBook 12"  Ultrabook      Intel Core M m3 1.2GHz
# 15        Apple        MacBook Pro  Ultrabook        Intel Core i5 2.3GHz
# 16         Dell      Inspiron 3567   Notebook  Intel Core i7 7500U 2.7GHz
# 17        Apple        MacBook Pro  Ultrabook        Intel Core i7 2.9GHz
# 18       Lenovo  IdeaPad 320-15IKB   Notebook  Intel Core i3 7100U 2.4GHz
# 19         Dell             XPS 13  Ultrabook  Intel Core i5 8250U 1.6GHz
#
#                 Storage                           GPU Operating System  \
# 0             128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1   128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2             256GB SSD         Intel HD Graphics 620            No OS
# 3             512GB SSD            AMD Radeon Pro 455            macOS
# 4             256GB SSD  Intel Iris Plus Graphics 650            macOS
# 5             500GB HDD                 AMD Radeon R5          Windows
# 6   256GB Flash Storage       Intel Iris Pro Graphics           Mac OS
# 7   256GB Flash Storage        Intel HD Graphics 6000            macOS
# 8             512GB SSD          Nvidia GeForce MX150          Windows
# 9             256GB SSD        Intel UHD Graphics 620          Windows
# 10            500GB HDD         Intel HD Graphics 620            No OS
# 11            500GB HDD         Intel HD Graphics 520            No OS
# 12            256GB SSD            AMD Radeon Pro 555            macOS
# 13            256GB SSD            AMD Radeon R5 M430          Windows
# 14            256GB SSD         Intel HD Graphics 615            macOS
# 15            256GB SSD  Intel Iris Plus Graphics 640            macOS
# 16            256GB SSD            AMD Radeon R5 M430          Windows
# 17            512GB SSD            AMD Radeon Pro 560            macOS
# 18              1TB HDD          Nvidia GeForce 940MX            No OS
# 19            128GB SSD        Intel UHD Graphics 620          Windows
#
#           Price  Weight  RAM  TouchScreen  Ips         ppi  resolution
# 0   11912523.48    1.37    8            0    1  226.983005     4096000
# 1    7993374.48    1.34    8            0    0  127.677940     1296000
# 2    5112900.00    1.86    8            0    0  141.211998     2073600
# 3   22563005.40    1.83   16            0    1  220.534624     5184000
# 4   16037611.20    1.37    8            0    1  226.983005     4096000
# 5    3556800.00    2.10    4            0    0  100.454670     1049088
# 6   19028613.24    2.04   16            0    1  220.534624     5184000
# 7   10303160.40    1.34    8            0    0  127.677940     1296000
# 8   13293540.00    1.30   16            0    0  157.350512     2073600
# 9    6846840.00    1.60    8            0    1  157.350512     2073600
# 10   3502558.80    1.86    4            0    0  100.454670     1049088
# 11   3067651.08    1.86    4            0    0  141.211998     2073600
# 12  21696213.24    1.83   16            0    1  220.534624     5184000
# 13   4436218.80    2.20    4            0    0  141.211998     2073600
# 14  11225260.80    0.92    8            0    1  226.415547     3317760
# 15  13502946.60    1.37    8            0    1  226.983005     4096000
# 16   6624540.00    2.20    8            0    0  141.211998     2073600
# 17  25413336.00    1.83   16            0    1  220.534624     5184000
# 18   4437108.00    2.20    8            0    0  141.211998     2073600
# 19   8705268.00    1.22    8            1    1  165.632118     2073600

# %%
data['cpu'] = data['CPU'].apply(lambda x: " ".join(x.split()[0:3]))
data.head()
# Out:
#   Manufacturer   Model Name   Category                         CPU  \
# 0        Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz
# 1        Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz
# 2           HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz
# 3        Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz
# 4        Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#          Price  Weight  RAM  TouchScreen  Ips         ppi  resolution  \
# 0  11912523.48    1.37    8            0    1  226.983005     4096000
# 1   7993374.48    1.34    8            0    0  127.677940     1296000
# 2   5112900.00    1.86    8            0    0  141.211998     2073600
# 3  22563005.40    1.83   16            0    1  220.534624     5184000
# 4  16037611.20    1.37    8            0    1  226.983005     4096000
#
#              cpu
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# 4  Intel Core i5

# %% [markdown]
# Creating a function and dividing the CPUs to 5 Categories:
# <ul>
#     <li>Intel i3</li>
#     <li>Intel i5</li>
#     <li>Intel i7</li>
#     <li>Other Intel Processors</li>
#     <li>AMD</li>
# </ul>

# %%
def fetch_processor(text):
    if text in ['Intel Core i5','Intel Core i7','Intel Core i3']:
        return text
    elif text.split()[0] == 'Intel':
        return 'Other Intel Processor'
    else:
        return 'AMD Processor'

# %%
data['Cpu brand'] = data['cpu'].apply(fetch_processor)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category                         CPU  \
# 0        Apple  MacBook Pro  Ultrabook        Intel Core i5 2.3GHz
# 1        Apple  Macbook Air  Ultrabook        Intel Core i5 1.8GHz
# 2           HP       250 G6   Notebook  Intel Core i5 7200U 2.5GHz
# 3        Apple  MacBook Pro  Ultrabook        Intel Core i7 2.7GHz
# 4        Apple  MacBook Pro  Ultrabook        Intel Core i5 3.1GHz
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#          Price  Weight  RAM  TouchScreen  Ips         ppi  resolution  \
# 0  11912523.48    1.37    8            0    1  226.983005     4096000
# 1   7993374.48    1.34    8            0    0  127.677940     1296000
# 2   5112900.00    1.86    8            0    0  141.211998     2073600
# 3  22563005.40    1.83   16            0    1  220.534624     5184000
# 4  16037611.20    1.37    8            0    1  226.983005     4096000
#
#              cpu      Cpu brand
# 0  Intel Core i5  Intel Core i5
# 1  Intel Core i5  Intel Core i5
# 2  Intel Core i5  Intel Core i5
# 3  Intel Core i7  Intel Core i7
# 4  Intel Core i5  Intel Core i5

# %%
data['Clock Speed'] = data['CPU'].str.findall(r'(\d+\.?\d?)').apply(lambda x: x[-1] if len(x) > 0 else 0)

data.sample(20)
# Out:
#     Manufacturer                       Model Name   Category  \
# 174       Lenovo  B51-80 (i5-6200U/8GB/1TB/Radeon   Notebook
# 889       Lenovo                IdeaPad 110-17ACL   Notebook
# 392         Acer                         Aspire 5   Notebook
# 135           HP                      Spectre Pro  Ultrabook
# 117         Acer                   Aspire F5-573G   Notebook
# 272         Dell                    Inspiron 3552   Notebook
# 610       Lenovo                     Thinkpad P51   Notebook
# 961       Lenovo                    ThinkPad X270  Ultrabook
# 505       Lenovo                      ThinkPad 13   Notebook
# 249        Apple                      MacBook Pro  Ultrabook
# 45            HP                      ProBook 440   Notebook
# 836         Asus               Rog GL702VS-BA023T     Gaming
# 742      Toshiba                  Tecra X40-D-10G   Notebook
# 842           HP                      ProBook 470   Notebook
# 435         Asus                        Rog Strix     Gaming
# 906           HP                    Elitebook 820    Netbook
# 280       Lenovo                IdeaPad 320-17IKB   Notebook
# 282       Lenovo               Legion Y520-15IKBN     Gaming
# 227         Asus          Vivobook X541UV-DM1217T   Notebook
# 269         Asus                      Rog GL502VS     Gaming
#
#                                       CPU               Storage  \
# 174            Intel Core i5 6200U 2.3GHz               1TB HDD
# 889             AMD A4-Series 7210 2.2GHz             500GB HDD
# 392            Intel Core i5 8250U 1.6GHz               1TB HDD
# 135            Intel Core i7 6500U 2.5GHz             512GB SSD
# 117            Intel Core i5 7200U 2.5GHz  256GB SSD +  1TB HDD
# 272  Intel Pentium Quad Core N3710 1.6GHz             500GB HDD
# 610         Intel Xeon E3-1535M v6 3.1GHz               1TB SSD
# 961            Intel Core i5 7300U 2.6GHz             256GB SSD
# 505            Intel Core i5 7200U 2.5GHz             256GB SSD
# 249                  Intel Core i5 3.1GHz             512GB SSD
# 45             Intel Core i7 7500U 2.7GHz             256GB SSD
# 836           Intel Core i7 7700HQ 2.8GHz  256GB SSD +  1TB HDD
# 742            Intel Core i5 7200U 2.5GHz             256GB SSD
# 842            Intel Core i5 7200U 2.5GHz               1TB HDD
# 435                 AMD Ryzen 1600 3.2GHz  256GB SSD +  1TB HDD
# 906            Intel Core i7 7500U 2.7GHz             512GB SSD
# 280            Intel Core i7 7500U 2.7GHz  128GB SSD +  1TB HDD
# 282           Intel Core i5 7300HQ 2.5GHz             256GB SSD
# 227            Intel Core i5 7200U 2.5GHz             256GB SSD
# 269           Intel Core i7 6700HQ 2.6GHz  256GB SSD +  1TB HDD
#
#                               GPU Operating System        Price  Weight  RAM  \
# 174            AMD Radeon R5 M330            No OS   5326308.00    2.32    8
# 889                 AMD Radeon R3          Windows   3370068.00    2.80    4
# 392          Nvidia GeForce MX130          Windows   6170959.08    2.20   12
# 135         Intel HD Graphics 520          Windows  17508348.00    1.16    8
# 117       Nvidia GeForce GTX 950M          Windows   7104708.00    2.40    8
# 272             Intel HD Graphics            Linux   2881008.00    2.20    4
# 610          Nvidia Quadro M2200M          Windows  43561908.00    2.50   32
# 961         Intel HD Graphics 620          Windows  15649920.00    1.36    8
# 505         Intel HD Graphics 620          Windows   8438508.00    1.44    8
# 249  Intel Iris Plus Graphics 650            macOS  18139680.00    1.37    8
# 45           Nvidia GeForce 930MX          Windows  10540843.56    1.64    8
# 836       Nvidia GeForce GTX 1070          Windows  21509748.00    2.90   16
# 742         Intel HD Graphics 620          Windows  13649220.00    1.25    8
# 842          Nvidia GeForce 930MX          Windows   8091720.00    2.63    8
# 435             AMD Radeon RX 580          Windows  15071940.00    3.20    8
# 906         Intel HD Graphics 620          Windows  13186836.00    1.26    8
# 280          Nvidia GeForce 940MX          Windows   7638228.00    2.80    6
# 282       Nvidia GeForce GTX 1050          Windows   7371468.00    2.50    8
# 227         Nvidia GeForce 920MX           Windows   6837948.00    2.00    8
# 269       Nvidia GeForce GTX 1070          Windows  20673900.00    2.34   16
#
#      TouchScreen  Ips         ppi  resolution                  cpu  \
# 174            0    0  141.211998     2073600        Intel Core i5
# 889            0    0  106.113062     1440000   AMD A4-Series 7210
# 392            0    1  100.454670     1049088        Intel Core i5
# 135            0    0  165.632118     2073600        Intel Core i7
# 117            0    0  141.211998     2073600        Intel Core i5
# 272            0    0  100.454670     1049088   Intel Pentium Quad
# 610            0    1  282.423996     8294400  Intel Xeon E3-1535M
# 961            0    1  176.232574     2073600        Intel Core i5
# 505            0    0  165.632118     2073600        Intel Core i5
# 249            0    1  226.983005     4096000        Intel Core i5
# 45             0    0  157.350512     2073600        Intel Core i7
# 836            0    0  127.335675     2073600        Intel Core i7
# 742            1    1  157.350512     2073600        Intel Core i5
# 842            0    0  106.113062     1440000        Intel Core i5
# 435            0    0  127.335675     2073600       AMD Ryzen 1600
# 906            0    0  176.232574     2073600        Intel Core i7
# 280            0    0  106.113062     1440000        Intel Core i7
# 282            0    1  141.211998     2073600        Intel Core i5
# 227            0    0  141.211998     2073600        Intel Core i5
# 269            0    1  141.211998     2073600        Intel Core i7
#
#                  Cpu brand Clock Speed
# 174          Intel Core i5         2.3
# 889          AMD Processor         2.2
# 392          Intel Core i5         1.6
# 135          Intel Core i7         2.5
# 117          Intel Core i5         2.5
# 272  Other Intel Processor         1.6
# 610  Other Intel Processor         3.1
# 961          Intel Core i5         2.6
# 505          Intel Core i5         2.5
# 249          Intel Core i5         3.1
# 45           Intel Core i7         2.7
# 836          Intel Core i7         2.8
# 742          Intel Core i5         2.5
# 842          Intel Core i5         2.5
# 435          AMD Processor         3.2
# 906          Intel Core i7         2.7
# 280          Intel Core i7         2.7
# 282          Intel Core i5         2.5
# 227          Intel Core i5         2.5
# 269          Intel Core i7         2.6

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = data['Clock Speed'], y = data['Price'])
# Out:
# <Axes: xlabel='Clock Speed', ylabel='Price'>

# %%
mean_clock_speed = data['Clock Speed'].astype('float64').mode()

# %%
data['Clock Speed'] = data['Clock Speed'].apply(lambda x: mean_clock_speed[0] if x == "0" else x)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = data['Clock Speed'], y = data['Price'])
# Out:
# <Axes: xlabel='Clock Speed', ylabel='Price'>

# %%
plt.figure(figsize=(10,5))
data['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = data['Cpu brand'], y = data['Price'])
# Out:
# <Axes: xlabel='Cpu brand', ylabel='Price'>

# %%
data.drop(columns=['CPU','cpu'],inplace=True)
data.head()
# Out:
#   Manufacturer   Model Name   Category              Storage  \
# 0        Apple  MacBook Pro  Ultrabook            128GB SSD
# 1        Apple  Macbook Air  Ultrabook  128GB Flash Storage
# 2           HP       250 G6   Notebook            256GB SSD
# 3        Apple  MacBook Pro  Ultrabook            512GB SSD
# 4        Apple  MacBook Pro  Ultrabook            256GB SSD
#
#                             GPU Operating System        Price  Weight  RAM  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48    1.37    8
# 1        Intel HD Graphics 6000            macOS   7993374.48    1.34    8
# 2         Intel HD Graphics 620            No OS   5112900.00    1.86    8
# 3            AMD Radeon Pro 455            macOS  22563005.40    1.83   16
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20    1.37    8
#
#    TouchScreen  Ips         ppi  resolution      Cpu brand Clock Speed
# 0            0    1  226.983005     4096000  Intel Core i5         2.3
# 1            0    0  127.677940     1296000  Intel Core i5         1.8
# 2            0    0  141.211998     2073600  Intel Core i5         2.5
# 3            0    1  220.534624     5184000  Intel Core i7         2.7
# 4            0    1  226.983005     4096000  Intel Core i5         3.1

# %%
data['RAM'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = data['RAM'], y = data['Price'])
# Out:
# <Axes: xlabel='RAM', ylabel='Price'>

# %%
data['Storage'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          224
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1TB Hybrid                         9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 1GB SSD                            5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 512GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 512GB SSD +  1TB Hybrid            1
# 256GB SSD +  1TB Hybrid            1
# Name: Storage, dtype: int64

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category              Storage  \
# 0        Apple  MacBook Pro  Ultrabook            128GB SSD
# 1        Apple  Macbook Air  Ultrabook  128GB Flash Storage
# 2           HP       250 G6   Notebook            256GB SSD
# 3        Apple  MacBook Pro  Ultrabook            512GB SSD
# 4        Apple  MacBook Pro  Ultrabook            256GB SSD
#
#                             GPU Operating System        Price  Weight  RAM  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48    1.37    8
# 1        Intel HD Graphics 6000            macOS   7993374.48    1.34    8
# 2         Intel HD Graphics 620            No OS   5112900.00    1.86    8
# 3            AMD Radeon Pro 455            macOS  22563005.40    1.83   16
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20    1.37    8
#
#    TouchScreen  Ips         ppi  resolution      Cpu brand Clock Speed
# 0            0    1  226.983005     4096000  Intel Core i5         2.3
# 1            0    0  127.677940     1296000  Intel Core i5         1.8
# 2            0    0  141.211998     2073600  Intel Core i5         2.5
# 3            0    1  220.534624     5184000  Intel Core i7         2.7
# 4            0    1  226.983005     4096000  Intel Core i5         3.1

# %%
# data['Storage'] = data['Storage'].astype(str).replace('\.0','')
# data['Storage'] = data['Storage'].astype(str).replace('GB','')
# data['Storage'] = data['Storage'].astype(str).replace('TB','000')
# data.sample(20)

# %%
new = data['Storage'].str.split('+',n=1,expand=True)
print(new)
# data['Storage'].shape
data['first'] = new[0]
data['first'] = data['first'].str.strip()
data['sec'] = new[1]
# Out:
#                        0     1
# 0              128GB SSD  None
# 1    128GB Flash Storage  None
# 2              256GB SSD  None
# 3              512GB SSD  None
# 4              256GB SSD  None
# ..                   ...   ...
# 320            128GB SSD  None
# 321            512GB SSD  None
# 322   64GB Flash Storage  None
# 323              1TB HDD  None
# 324            500GB HDD  None
#
# [1302 rows x 2 columns]

# %%
data['l1hdd'] = data['first'].apply(lambda x: 1 if "HDD" in x else 0)
data['l1ssd'] = data['first'].apply(lambda x: 1 if "SSD" in x else 0)
data['l1hybrid'] = data['first'].apply(lambda x: 1 if "Hybrid" in x else 0)
data['l1fs'] = data['first'].apply(lambda x: 1 if "Flash Storage" in x else 0)
data['first'] = data['first'].str.replace(r'\D','') 
# str.replace(r'\D','') is replacing all non-digit characters in the string
data['sec'].fillna('0',inplace=True)
# Out:
# <ipython-input-601-354fc04aae49>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['first'] = data['first'].str.replace(r'\D','')

# %%
data['l2hdd'] = data['sec'].apply(lambda x: 1 if "HDD" in x else 0)
data['l2ssd'] = data['sec'].apply(lambda x: 1 if "SSD" in x else 0)
data['l2hybrid'] = data['sec'].apply(lambda x: 1 if "Hybrid" in x else 0)
data['l2fs'] = data['sec'].apply(lambda x: 1 if "Flash Storage" in x else 0)
data['sec'] = data['sec'].str.replace(r'\D','')
# Out:
# <ipython-input-602-e5a3f235537f>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['sec'] = data['sec'].str.replace(r'\D','')

# %%
data['first'] = data['first'].astype('int')
data['sec'] = data['sec'].astype('int')

# %%
data['HDD'] = data['first']*data['l1hdd'] + data['sec']*data['l2hdd']
data['SSD'] = data['first']*data['l1ssd'] + data['sec']*data['l2ssd']
data['Hybrid'] = data['first']*data['l1hybrid'] + data['sec']*data['l2hybrid']
data['FS'] = data['first']*data['l1fs'] + data['sec']*data['l2fs']

data.drop(columns=['first','sec','l1hdd','l1ssd','l1hybrid','l1fs','l2hdd','l2ssd','l2fs','l2hybrid'],inplace=True)

# %%
data.head()
# Out:
#   Manufacturer   Model Name   Category              Storage  \
# 0        Apple  MacBook Pro  Ultrabook            128GB SSD
# 1        Apple  Macbook Air  Ultrabook  128GB Flash Storage
# 2           HP       250 G6   Notebook            256GB SSD
# 3        Apple  MacBook Pro  Ultrabook            512GB SSD
# 4        Apple  MacBook Pro  Ultrabook            256GB SSD
#
#                             GPU Operating System        Price  Weight  RAM  \
# 0  Intel Iris Plus Graphics 640            macOS  11912523.48    1.37    8
# 1        Intel HD Graphics 6000            macOS   7993374.48    1.34    8
# 2         Intel HD Graphics 620            No OS   5112900.00    1.86    8
# 3            AMD Radeon Pro 455            macOS  22563005.40    1.83   16
# 4  Intel Iris Plus Graphics 650            macOS  16037611.20    1.37    8
#
#    TouchScreen  Ips         ppi  resolution      Cpu brand Clock Speed  HDD  \
# 0            0    1  226.983005     4096000  Intel Core i5         2.3    0
# 1            0    0  127.677940     1296000  Intel Core i5         1.8    0
# 2            0    0  141.211998     2073600  Intel Core i5         2.5    0
# 3            0    1  220.534624     5184000  Intel Core i7         2.7    0
# 4            0    1  226.983005     4096000  Intel Core i5         3.1    0
#
#    SSD  Hybrid   FS
# 0  128       0    0
# 1    0       0  128
# 2  256       0    0
# 3  512       0    0
# 4  256       0    0

# %%
data.drop(columns=['Storage'],inplace=True)
data.sample(5)
# Out:
#     Manufacturer                        Model Name            Category  \
# 500         Asus                   VivoBook E201NA             Netbook
# 771      Samsung                        Notebook 9  2 in 1 Convertible
# 183      Toshiba                     Satellite Pro            Notebook
# 553           HP  17-X047na (i3-6006U/8GB/1TB/W10)            Notebook
# 51          Acer                   Aspire A515-51G            Notebook
#
#                        GPU Operating System       Price  Weight  RAM  \
# 500  Intel HD Graphics 500          Windows   3023280.0    1.20    4
# 771         AMD Radeon 540          Windows  15996708.0    1.71   16
# 183  Intel HD Graphics 620          Windows   7051356.0    2.00    8
# 553  Intel HD Graphics 520          Windows   4838581.8    2.65    8
# 51    Nvidia GeForce MX150          Windows   7478172.0    2.20    8
#
#      TouchScreen  Ips         ppi  resolution              Cpu brand  \
# 500            0    0  135.094211     1049088  Other Intel Processor
# 771            1    0  146.860478     2073600          Intel Core i7
# 183            0    0  100.454670     1049088          Intel Core i5
# 553            0    0  106.113062     1440000          Intel Core i3
# 51             0    1  141.211998     2073600          Intel Core i7
#
#     Clock Speed  HDD  SSD  Hybrid  FS
# 500         1.1    0    0       0  64
# 771         2.7    0  256       0   0
# 183         2.5    0  128       0   0
# 553           2    1    0       0   0
# 51          1.8    0  256       0   0

# %%
data = data.drop('Model Name',axis=1)
data.sample(5)
# Out:
#     Manufacturer            Category                    GPU Operating System  \
# 971         Dell           Ultrabook  Intel HD Graphics 520          Windows
# 294       Lenovo            Notebook      Intel HD Graphics          Windows
# 525       Lenovo            Notebook  Intel HD Graphics 520          Windows
# 699           HP            Notebook         AMD Radeon 530          Windows
# 129       Lenovo  2 in 1 Convertible  Intel HD Graphics 520          Windows
#
#            Price  Weight  RAM  TouchScreen  Ips         ppi  resolution  \
# 971  17454818.16    1.50    8            1    0  209.800683     3686400
# 294   2036268.00    1.50    2            0    0  111.935204     1049088
# 525  11915280.00    2.02    8            0    0  157.350512     2073600
# 699   6126588.00    2.10    4            0    1  141.211998     2073600
# 129   7709364.00    2.10    4            1    1  141.211998     2073600
#
#                  Cpu brand Clock Speed  HDD  SSD  Hybrid  FS
# 971          Intel Core i7         2.6    0  256       0   0
# 294  Other Intel Processor         1.6    0    0       0  64
# 525          Intel Core i5         2.3    0  256       0   0
# 699          Intel Core i7         2.7  500    0       0   0
# 129          Intel Core i5         2.3    0  256       0   0

# %%
data = data.rename(columns={'Ips':'IPS'})
data.sample(20)
# Out:
#     Manufacturer            Category                      GPU  \
# 113           HP            Notebook   Intel UHD Graphics 620
# 943      Toshiba            Notebook    Intel HD Graphics 520
# 789         Dell              Gaming  Nvidia GeForce GTX 1050
# 852         Dell            Notebook       AMD Radeon R7 M445
# 72        Lenovo            Notebook    Intel HD Graphics 520
# 310       Lenovo            Notebook    Intel HD Graphics 620
# 203       Lenovo           Ultrabook      Nvidia GeForce 920M
# 60          Dell            Notebook           AMD Radeon 530
# 77          Dell            Notebook   Intel UHD Graphics 620
# 228           HP            Notebook    Intel HD Graphics 620
# 320           HP            Notebook    Intel HD Graphics 620
# 524         Dell            Notebook           AMD Radeon 530
# 374         Dell  2 in 1 Convertible   Intel UHD Graphics 620
# 603          MSI              Gaming  Nvidia GeForce GTX 970M
# 229           HP            Notebook      AMD FirePro W4190M
# 597       Lenovo            Notebook    Intel HD Graphics 630
# 470           HP  2 in 1 Convertible   Intel UHD Graphics 620
# 339         Dell            Notebook     Nvidia GeForce 940MX
# 223       Lenovo            Notebook     Nvidia GeForce 920MX
# 662       Lenovo            Notebook    Intel HD Graphics 520
#
#     Operating System        Price  Weight  RAM  TouchScreen  IPS         ppi  \
# 113          Windows   6420024.00    1.63    4            0    1  111.935204
# 943          Windows   9950148.00    2.20    8            0    0  100.454670
# 789          Windows   8758620.00    2.62    8            0    0  141.211998
# 852            Linux   7691580.00    2.83    8            0    0  127.335675
# 72           Windows  23297040.00    1.10   16            0    1  209.800683
# 310          Windows   8883108.00    1.10    8            0    1  165.632118
# 203          Windows   7389252.00    1.54    6            0    0  141.211998
# 60           Windows  11550708.00    2.80   16            0    0  127.335675
# 77           Windows   7602660.00    2.02    8            0    0  141.211998
# 228          Windows   5148468.00    1.91    8            0    0  100.454670
# 320          Windows  11488464.00    1.48    8            0    0  157.350512
# 524            Linux   7904988.00    2.80    8            0    1  127.335675
# 374          Windows   7727236.92    1.62    8            1    0  165.632118
# 603          Windows  19553508.00    4.14   16            0    0  127.335675
# 229          Windows  11283948.00    1.90    8            0    0  141.211998
# 597          Windows  13106808.00    1.70    8            0    1  157.350512
# 470          Windows  17775108.00    1.29    8            1    1  331.264236
# 339          Windows  10161333.00    2.00    8            0    0  141.211998
# 223            No OS   5593068.00    2.20    8            0    0  100.454670
# 662          Windows   4757220.00    2.20    4            0    0  141.211998
#
#      resolution      Cpu brand Clock Speed  HDD  SSD  Hybrid  FS
# 113     1049088  Intel Core i5         1.6  500    0       0   0
# 943     1049088  Intel Core i5         2.3    0  256       0   0
# 789     2073600  Intel Core i5         2.5    0  256       0   0
# 852     2073600  Intel Core i7         2.7    1    0       0   0
# 72      3686400  Intel Core i7         2.6    0  256       0   0
# 310     2073600  Intel Core i5         2.5    0  256       0   0
# 203     2073600  Intel Core i7         2.7    0  256       0   0
# 60      2073600  Intel Core i7         1.8    2  256       0   0
# 77      2073600  Intel Core i7         1.8    1  128       0   0
# 228     1049088  Intel Core i5         2.5    0  256       0   0
# 320     2073600  Intel Core i7         2.7    0  256       0   0
# 524     2073600  Intel Core i5         1.6    1  128       0   0
# 374     2073600  Intel Core i7         1.8    0  256       0   0
# 603     2073600  Intel Core i7         2.7    1  128       0   0
# 229     2073600  Intel Core i7         2.7    1    0       0   0
# 597     2073600  Intel Core i5         2.5    0  256       0   0
# 470     8294400  Intel Core i7         1.8    0  512       0   0
# 339     2073600  Intel Core i5         1.6    0  256       0   0
# 223     1049088  Intel Core i7         2.5  500    0       0   0
# 662     2073600  Intel Core i5         2.3  500    0       0   0

# %%
data['HDD'] = data['HDD'].apply(lambda x: x*1000 if x==1 or x==2 else x)
data.sample(20)
# Out:
#     Manufacturer            Category                             GPU  \
# 456         Dell            Notebook         Nvidia GeForce GTX 1060
# 727         Dell  2 in 1 Convertible           Intel HD Graphics 620
# 920         Dell            Notebook              AMD Radeon R5 M420
# 77            HP            Notebook           Intel HD Graphics 520
# 477       Lenovo            Notebook           Intel HD Graphics 620
# 158           HP         Workstation            Nvidia Quadro M3000M
# 481         Dell            Notebook           Intel HD Graphics 620
# 283         Asus           Ultrabook           Intel HD Graphics 515
# 392         Acer            Notebook            Nvidia GeForce MX130
# 248           HP            Notebook          Intel UHD Graphics 620
# 151           HP              Gaming         Nvidia GeForce GTX 1060
# 118         Asus            Notebook            Nvidia GeForce 920MX
# 373       Lenovo            Notebook                   AMD Radeon R5
# 168         Acer            Notebook            Nvidia GeForce MX150
# 240       Lenovo              Gaming  Nvidia GeForce GTX 960<U+039C>
# 538           HP              Gaming         Nvidia GeForce GTX 1060
# 188       Lenovo            Notebook           Intel HD Graphics 620
# 214           HP            Notebook           Intel HD Graphics 620
# 185         Dell            Notebook            Nvidia GeForce 150MX
# 42          Dell  2 in 1 Convertible           Intel HD Graphics 520
#
#     Operating System        Price  Weight  RAM  TouchScreen  IPS         ppi  \
# 456          Windows  18193032.00    4.42    8            0    1  127.335675
# 727          Windows   5770908.00    1.71    4            1    0  165.632118
# 920          Windows   6090931.08    2.18    4            0    0  100.454670
# 77           Windows   6270193.80    2.31    4            0    0  100.454670
# 477          Windows  12128688.00    1.70    8            0    0  157.350512
# 158          Windows  35118064.80    3.00    8            0    1  127.335675
# 481          Windows   5216047.20    2.18    4            0    0  100.454670
# 283          Windows   6482268.00    1.20    8            0    1  165.632118
# 392          Windows   6170959.08    2.20   12            0    1  100.454670
# 248          Windows   6002100.00    1.49    4            0    1  165.632118
# 151          Windows  10039068.00    3.35    8            0    1  127.335675
# 118          Windows   5015088.00    2.00    4            0    0  127.335675
# 373          Windows   4348188.00    2.60    4            0    0  106.113062
# 168          Windows   7593768.00    3.00    8            0    1  127.335675
# 240          Windows  11310624.00    2.60    8            0    1  141.211998
# 538          Windows  15996708.00    2.62   12            0    0  127.335675
# 188          Windows  12359880.00    1.95    8            0    1  141.211998
# 214          Windows   4312620.00    1.86    4            0    0  100.454670
# 185          Windows  13773708.00    2.77   16            1    0  127.335675
# 42           Windows   7077943.08    2.08    4            1    1  141.211998
#
#      resolution              Cpu brand Clock Speed   HDD  SSD  Hybrid  FS
# 456     2073600          Intel Core i7         2.7  1000    0       0   0
# 727     2073600          Intel Core i3         2.4  1000    0       0   0
# 920     1049088          Intel Core i5         2.5  1000    0       0   0
# 77      1049088          Intel Core i3         2.3   500    0       0   0
# 477     2073600          Intel Core i5         2.5     0    1       0   0
# 158     2073600          Intel Core i7         2.6     0  256       0   0
# 481     1049088          Intel Core i3         2.4  1000    0       0   0
# 283     2073600  Other Intel Processor         0.9     0  512       0   0
# 392     1049088          Intel Core i5         1.6  1000    0       0   0
# 248     2073600          Intel Core i5         1.6   500    0       0   0
# 151     2073600          Intel Core i5         2.3  1000  128       0   0
# 118     2073600          Intel Core i3           2  1000    0       0   0
# 373     1440000          AMD Processor         2.2     0  128       0   0
# 168     2073600          Intel Core i5         1.6     0  256       0   0
# 240     2073600          Intel Core i7         2.6  1000  128       0   0
# 538     2073600          Intel Core i7         2.8  1000    0       0   0
# 188     2073600          Intel Core i5         2.5     0  256       0   0
# 214     1049088          Intel Core i5         2.5   500    0       0   0
# 185     2073600          Intel Core i7         1.8     0  512       0   0
# 42      2073600          Intel Core i3         2.3  1000    0       0   0

# %%
data.corr()['Price']
# Out:
# <ipython-input-610-6b59db53f049>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()['Price']
# Price          1.000000
# Weight         0.210166
# RAM            0.742802
# TouchScreen    0.189931
# IPS            0.252799
# ppi            0.473125
# resolution     0.516261
# HDD           -0.099121
# SSD            0.545948
# Hybrid        -0.004750
# FS            -0.040414
# Name: Price, dtype: float64

# %% [markdown]
# Dropping Hybrid and Flash Storage as they have very less correlation with price

# %%
data.drop(columns={'Hybrid','FS'},inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 324
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      1302 non-null   object
#  1   Category          1302 non-null   object
#  2   GPU               1302 non-null   object
#  3   Operating System  1302 non-null   object
#  4   Price             1302 non-null   float64
#  5   Weight            1302 non-null   float64
#  6   RAM               1302 non-null   int64
#  7   TouchScreen       1302 non-null   int64
#  8   IPS               1302 non-null   int64
#  9   ppi               1302 non-null   float64
#  10  resolution        1302 non-null   int64
#  11  Cpu brand         1302 non-null   object
#  12  Clock Speed       1302 non-null   object
#  13  HDD               1302 non-null   int64
#  14  SSD               1302 non-null   int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 162.8+ KB

# %% [markdown]
# Converting to Indian Currency

# %%
data['Price'] = data['Price']/100
data.head(10)
# Out:
#   Manufacturer   Category                           GPU Operating System  \
# 0        Apple  Ultrabook  Intel Iris Plus Graphics 640            macOS
# 1        Apple  Ultrabook        Intel HD Graphics 6000            macOS
# 2           HP   Notebook         Intel HD Graphics 620            No OS
# 3        Apple  Ultrabook            AMD Radeon Pro 455            macOS
# 4        Apple  Ultrabook  Intel Iris Plus Graphics 650            macOS
# 5         Acer   Notebook                 AMD Radeon R5          Windows
# 6        Apple  Ultrabook       Intel Iris Pro Graphics           Mac OS
# 7        Apple  Ultrabook        Intel HD Graphics 6000            macOS
# 8         Asus  Ultrabook          Nvidia GeForce MX150          Windows
# 9         Acer  Ultrabook        Intel UHD Graphics 620          Windows
#
#          Price  Weight  RAM  TouchScreen  IPS         ppi  resolution  \
# 0  119125.2348    1.37    8            0    1  226.983005     4096000
# 1   79933.7448    1.34    8            0    0  127.677940     1296000
# 2   51129.0000    1.86    8            0    0  141.211998     2073600
# 3  225630.0540    1.83   16            0    1  220.534624     5184000
# 4  160376.1120    1.37    8            0    1  226.983005     4096000
# 5   35568.0000    2.10    4            0    0  100.454670     1049088
# 6  190286.1324    2.04   16            0    1  220.534624     5184000
# 7  103031.6040    1.34    8            0    0  127.677940     1296000
# 8  132935.4000    1.30   16            0    0  157.350512     2073600
# 9   68468.4000    1.60    8            0    1  157.350512     2073600
#
#        Cpu brand Clock Speed  HDD  SSD
# 0  Intel Core i5         2.3    0  128
# 1  Intel Core i5         1.8    0    0
# 2  Intel Core i5         2.5    0  256
# 3  Intel Core i7         2.7    0  512
# 4  Intel Core i5         3.1    0  256
# 5  AMD Processor           3  500    0
# 6  Intel Core i7         2.2    0    0
# 7  Intel Core i5         1.8    0    0
# 8  Intel Core i7         1.8    0  512
# 9  Intel Core i5         1.6    0  256

# %%
data['Price'] = data['Price'].round(decimals = 2)
data.head()
# Out:
#   Manufacturer   Category                           GPU Operating System  \
# 0        Apple  Ultrabook  Intel Iris Plus Graphics 640            macOS
# 1        Apple  Ultrabook        Intel HD Graphics 6000            macOS
# 2           HP   Notebook         Intel HD Graphics 620            No OS
# 3        Apple  Ultrabook            AMD Radeon Pro 455            macOS
# 4        Apple  Ultrabook  Intel Iris Plus Graphics 650            macOS
#
#        Price  Weight  RAM  TouchScreen  IPS         ppi  resolution  \
# 0  119125.23    1.37    8            0    1  226.983005     4096000
# 1   79933.74    1.34    8            0    0  127.677940     1296000
# 2   51129.00    1.86    8            0    0  141.211998     2073600
# 3  225630.05    1.83   16            0    1  220.534624     5184000
# 4  160376.11    1.37    8            0    1  226.983005     4096000
#
#        Cpu brand Clock Speed  HDD  SSD
# 0  Intel Core i5         2.3    0  128
# 1  Intel Core i5         1.8    0    0
# 2  Intel Core i5         2.5    0  256
# 3  Intel Core i7         2.7    0  512
# 4  Intel Core i5         3.1    0  256

# %%
data['gpu'] = data['GPU'].apply(lambda x:x.split()[0])
data['gpu'].value_counts()
# Out:
# Intel     722
# Nvidia    399
# AMD       180
# ARM         1
# Name: gpu, dtype: int64

# %%
data = data[data['gpu'] != 'ARM']
data['gpu'].value_counts()
# Out:
# Intel     722
# Nvidia    399
# AMD       180
# Name: gpu, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = data['gpu'], y = data['Price'])
# Out:
# <Axes: xlabel='gpu', ylabel='Price'>

# %%
data = data.drop('GPU',axis=1)
data.head()
# Out:
#   Manufacturer   Category Operating System      Price  Weight  RAM  \
# 0        Apple  Ultrabook            macOS  119125.23    1.37    8
# 1        Apple  Ultrabook            macOS   79933.74    1.34    8
# 2           HP   Notebook            No OS   51129.00    1.86    8
# 3        Apple  Ultrabook            macOS  225630.05    1.83   16
# 4        Apple  Ultrabook            macOS  160376.11    1.37    8
#
#    TouchScreen  IPS         ppi  resolution      Cpu brand Clock Speed  HDD  \
# 0            0    1  226.983005     4096000  Intel Core i5         2.3    0
# 1            0    0  127.677940     1296000  Intel Core i5         1.8    0
# 2            0    0  141.211998     2073600  Intel Core i5         2.5    0
# 3            0    1  220.534624     5184000  Intel Core i7         2.7    0
# 4            0    1  226.983005     4096000  Intel Core i5         3.1    0
#
#    SSD    gpu
# 0  128  Intel
# 1    0  Intel
# 2  256  Intel
# 3  512    AMD
# 4  256  Intel

# %%
data['Operating System'].value_counts()
# Out:
# Windows      1124
# No OS          66
# Linux          62
# Chrome OS      26
# macOS          13
# Mac OS          8
# Android         2
# Name: Operating System, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = data['Operating System'], y = data['Price'])
# Out:
# <Axes: xlabel='Operating System', ylabel='Price'>

# %%
def merge_os(os):
    if os == 'Windows':
        return os
    elif os == 'macOS' or os == 'Mac OS':
        return 'Mac'
    elif os == 'Linux':
        return os
    else:
        return 'Others/No OS'

# %%
data['OS'] = data['Operating System'].apply(merge_os)
data.head()
# Out:
#   Manufacturer   Category Operating System      Price  Weight  RAM  \
# 0        Apple  Ultrabook            macOS  119125.23    1.37    8
# 1        Apple  Ultrabook            macOS   79933.74    1.34    8
# 2           HP   Notebook            No OS   51129.00    1.86    8
# 3        Apple  Ultrabook            macOS  225630.05    1.83   16
# 4        Apple  Ultrabook            macOS  160376.11    1.37    8
#
#    TouchScreen  IPS         ppi  resolution      Cpu brand Clock Speed  HDD  \
# 0            0    1  226.983005     4096000  Intel Core i5         2.3    0
# 1            0    0  127.677940     1296000  Intel Core i5         1.8    0
# 2            0    0  141.211998     2073600  Intel Core i5         2.5    0
# 3            0    1  220.534624     5184000  Intel Core i7         2.7    0
# 4            0    1  226.983005     4096000  Intel Core i5         3.1    0
#
#    SSD    gpu            OS
# 0  128  Intel           Mac
# 1    0  Intel           Mac
# 2  256  Intel  Others/No OS
# 3  512    AMD           Mac
# 4  256  Intel           Mac

# %%
data.drop(columns=['Operating System'],inplace=True)
data.head()
# Out:
#   Manufacturer   Category      Price  Weight  RAM  TouchScreen  IPS  \
# 0        Apple  Ultrabook  119125.23    1.37    8            0    1
# 1        Apple  Ultrabook   79933.74    1.34    8            0    0
# 2           HP   Notebook   51129.00    1.86    8            0    0
# 3        Apple  Ultrabook  225630.05    1.83   16            0    1
# 4        Apple  Ultrabook  160376.11    1.37    8            0    1
#
#           ppi  resolution      Cpu brand Clock Speed  HDD  SSD    gpu  \
# 0  226.983005     4096000  Intel Core i5         2.3    0  128  Intel
# 1  127.677940     1296000  Intel Core i5         1.8    0    0  Intel
# 2  141.211998     2073600  Intel Core i5         2.5    0  256  Intel
# 3  220.534624     5184000  Intel Core i7         2.7    0  512    AMD
# 4  226.983005     4096000  Intel Core i5         3.1    0  256  Intel
#
#              OS
# 0           Mac
# 1           Mac
# 2  Others/No OS
# 3           Mac
# 4           Mac

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = data['OS'], y = data['Price'])
# Out:
# <Axes: xlabel='OS', ylabel='Price'>

# %%
corr_matrix = data.corr()
print(corr_matrix)
plt.figure(figsize=(16,5))
sns.heatmap(corr_matrix, annot=True)
plt.show()
# Out:
# <ipython-input-667-08a6dfcbab94>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
#                 Price    Weight       RAM  TouchScreen       IPS       ppi  \
# Price        1.000000  0.209664  0.742700     0.191624  0.253911  0.475017
# Weight       0.209664  1.000000  0.383264    -0.294406  0.018835 -0.324095
# RAM          0.742700  0.383264  1.000000     0.116459  0.208877  0.303479
# TouchScreen  0.191624 -0.294406  0.116459     1.000000  0.149537  0.455483
# IPS          0.253911  0.018835  0.208877     0.149537  1.000000  0.301855
# ppi          0.475017 -0.324095  0.303479     0.455483  0.301855  1.000000
# resolution   0.517262 -0.044517  0.395717     0.348801  0.248563  0.920146
# HDD         -0.099572  0.515127  0.092684    -0.215734 -0.092466 -0.304429
# SSD          0.545736 -0.093513  0.463556     0.216629  0.219370  0.412770
#
#              resolution       HDD       SSD
# Price          0.517262 -0.099572  0.545736
# Weight        -0.044517  0.515127 -0.093513
# RAM            0.395717  0.092684  0.463556
# TouchScreen    0.348801 -0.215734  0.216629
# IPS            0.248563 -0.092466  0.219370
# ppi            0.920146 -0.304429  0.412770
# resolution     1.000000 -0.126823  0.352741
# HDD           -0.126823  1.000000 -0.416791
# SSD            0.352741 -0.416791  1.000000

# %%
plt.figure(figsize=(10,6))
sns.histplot(np.log(data['Price']),kde=True)
plt.show()

# %% [markdown]
# <h3><center> Prediction Model</center></h3>

# %%
data.head(20)
# Out:
#    Manufacturer   Category      Price  Weight  RAM  TouchScreen  IPS  \
# 0         Apple  Ultrabook  119125.23    1.37    8            0    1
# 1         Apple  Ultrabook   79933.74    1.34    8            0    0
# 2            HP   Notebook   51129.00    1.86    8            0    0
# 3         Apple  Ultrabook  225630.05    1.83   16            0    1
# 4         Apple  Ultrabook  160376.11    1.37    8            0    1
# 5          Acer   Notebook   35568.00    2.10    4            0    0
# 6         Apple  Ultrabook  190286.13    2.04   16            0    1
# 7         Apple  Ultrabook  103031.60    1.34    8            0    0
# 8          Asus  Ultrabook  132935.40    1.30   16            0    0
# 9          Acer  Ultrabook   68468.40    1.60    8            0    1
# 10           HP   Notebook   35025.59    1.86    4            0    0
# 11           HP   Notebook   30676.51    1.86    4            0    0
# 12        Apple  Ultrabook  216962.13    1.83   16            0    1
# 13         Dell   Notebook   44362.19    2.20    4            0    0
# 14        Apple  Ultrabook  112252.61    0.92    8            0    1
# 15        Apple  Ultrabook  135029.47    1.37    8            0    1
# 16         Dell   Notebook   66245.40    2.20    8            0    0
# 17        Apple  Ultrabook  254133.36    1.83   16            0    1
# 18       Lenovo   Notebook   44371.08    2.20    8            0    0
# 19         Dell  Ultrabook   87052.68    1.22    8            1    1
#
#            ppi  resolution              Cpu brand Clock Speed   HDD  SSD  \
# 0   226.983005     4096000          Intel Core i5         2.3     0  128
# 1   127.677940     1296000          Intel Core i5         1.8     0    0
# 2   141.211998     2073600          Intel Core i5         2.5     0  256
# 3   220.534624     5184000          Intel Core i7         2.7     0  512
# 4   226.983005     4096000          Intel Core i5         3.1     0  256
# 5   100.454670     1049088          AMD Processor           3   500    0
# 6   220.534624     5184000          Intel Core i7         2.2     0    0
# 7   127.677940     1296000          Intel Core i5         1.8     0    0
# 8   157.350512     2073600          Intel Core i7         1.8     0  512
# 9   157.350512     2073600          Intel Core i5         1.6     0  256
# 10  100.454670     1049088          Intel Core i5         2.5   500    0
# 11  141.211998     2073600          Intel Core i3           2   500    0
# 12  220.534624     5184000          Intel Core i7         2.8     0  256
# 13  141.211998     2073600          Intel Core i3           2     0  256
# 14  226.415547     3317760  Other Intel Processor         1.2     0  256
# 15  226.983005     4096000          Intel Core i5         2.3     0  256
# 16  141.211998     2073600          Intel Core i7         2.7     0  256
# 17  220.534624     5184000          Intel Core i7         2.9     0  512
# 18  141.211998     2073600          Intel Core i3         2.4  1000    0
# 19  165.632118     2073600          Intel Core i5         1.6     0  128
#
#        gpu            OS
# 0    Intel           Mac
# 1    Intel           Mac
# 2    Intel  Others/No OS
# 3      AMD           Mac
# 4    Intel           Mac
# 5      AMD       Windows
# 6    Intel           Mac
# 7    Intel           Mac
# 8   Nvidia       Windows
# 9    Intel       Windows
# 10   Intel  Others/No OS
# 11   Intel  Others/No OS
# 12     AMD           Mac
# 13     AMD       Windows
# 14   Intel           Mac
# 15   Intel           Mac
# 16     AMD       Windows
# 17     AMD           Mac
# 18  Nvidia  Others/No OS
# 19   Intel       Windows

# %%
x = data.drop('Price',axis=1)
y = np.log(data['Price'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1301 entries, 0 to 324
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Manufacturer  1301 non-null   object
#  1   Category      1301 non-null   object
#  2   Price         1301 non-null   float64
#  3   Weight        1301 non-null   float64
#  4   RAM           1301 non-null   int64
#  5   TouchScreen   1301 non-null   int64
#  6   IPS           1301 non-null   int64
#  7   ppi           1301 non-null   float64
#  8   resolution    1301 non-null   int64
#  9   Cpu brand     1301 non-null   object
#  10  Clock Speed   1301 non-null   object
#  11  HDD           1301 non-null   int64
#  12  SSD           1301 non-null   int64
#  13  gpu           1301 non-null   object
#  14  OS            1301 non-null   object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 162.6+ KB

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error
from xgboost import XGBRegressor

# %% [markdown]
# ## Linear Regression

# %%
# df_subset = data.iloc[:,[0,1,9,12,13] ]
# print(df_subset)

# def plot_roc_curve(true_y, y_prob):
#     """
#     plots the roc curve based of the probabilities
#     """

#     fpr, tpr, thresholds = roc_curve(true_y, y_prob)
#     plt.plot(fpr, tpr)
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')


s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

lreg = LinearRegression()
pipe = Pipeline([
     ('s1',s1),
     ('lreg',lreg)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score: ', r2_score(y_test,y_pred))
print('Mean Absolute Error (MAE): ', mean_absolute_error(y_test,y_pred))
print(f'Mean Squared Error (MSE): ', mean_squared_error(y_test,y_pred))
print( f'Root Mean Squared Error (RMSE): ', mean_squared_error(y_test,y_pred, squared=False))


# from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve
# plot_roc_curve(y_test, y_pred)
# Out:
# R2 Score:  0.7905371713975362
# Mean Absolute Error (MAE):  0.2103907781401027
# Mean Squared Error (MSE):  0.07614365552466959
# Root Mean Squared Error (RMSE):  0.27594139871478074

# %% [markdown]
# ## Ridge Regression

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

rreg = Ridge(alpha=10)
pipe = Pipeline([
     ('s1',s1),
     ('Ridge',rreg)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))

# from sklearn.metrics import confusion_matrix
# mat=confusion_matrix(y_pred, y_test)
# print(mat)
# Out:
# R2 Score 0.7962623520990404
# MAE 0.21007948664560902

# %% [markdown]
# ## Lasso Regression

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

lreg = Lasso(alpha=0.001)
pipe = Pipeline([
     ('s1',s1),
     ('s2',lreg)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# from sklearn.metrics import confusion_matrix
# mat=confusion_matrix(y_pred, y_test)
# Out:
# R2 Score 0.793922309067924
# MAE 0.2118573313062143

# %% [markdown]
# ## KNN

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

knn = KNeighborsRegressor(n_neighbors=6)
pipe = Pipeline([
     ('s1',s1),
     ('s2',knn)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8252423495122345
# MAE 0.20051466654118028

# %% [markdown]
# ## Decision Tree

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

dtr = DecisionTreeRegressor(max_depth=8)
pipe = Pipeline([
     ('s1',s1),
     ('s2',dtr)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.7993965508457405
# MAE 0.20417976042768762

# %% [markdown]
# ## SVM

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

svm = SVR(kernel='rbf',C=10000,epsilon=0.1)
pipe = Pipeline([
     ('s1',s1),
     ('s2',svm)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.48397991777504534
# MAE 0.3544497619024068

# %% [markdown]
# ## Random Forest Regression

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

rrr = RandomForestRegressor(n_estimators=500,
                            random_state=3,
                            max_samples=0.7,
                            max_features=0.5,
                            max_depth=15)
pipe = Pipeline([
     ('s1',s1),
     ('s2',rrr)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8792112676814479
# MAE 0.1568527030387076

# %% [markdown]
# ## Extra Trees

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

xt = ExtraTreesRegressor(n_estimators=100,
                            random_state=3,
                            max_samples=0.7,
                            bootstrap=True,
                            max_features=0.5,
                            max_depth=15)
pipe = Pipeline([
     ('s1',s1),
     ('s2',xt)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8747193153807775
# MAE 0.16063878221526465

# %% [markdown]
# ## Ada Boost

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

s2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)
pipe = Pipeline([
     ('s1',s1),
     ('s2',s2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.7863716043752113
# MAE 0.22450936346192588

# %% [markdown]
# ## Gradient Boost

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

s2 = GradientBoostingRegressor(n_estimators=250)
pipe = Pipeline([
     ('s1',s1),
     ('s2',s2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8674656334889614
# MAE 0.16321028847361088

# %% [markdown]
# ## Xgboost

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

s2 = XGBRegressor(n_estimators=100,max_depth=3,learning_rate=0.5)
pipe = Pipeline([
('s1',s1),
('s2',s2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.878442624633063
# MAE 0.15843860313010844

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor, StackingRegressor

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

rf = RandomForestRegressor(n_estimators=500,random_state=3,max_samples=0.7,max_features=0.5,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=250,max_features=0.5)
xgb = XGBRegressor(n_estimators=100,learning_rate=0.5,max_depth=3)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,bootstrap=True,max_samples=0.7,max_features=0.5,max_depth=15)

s2 = VotingRegressor([('et',et),('rf',rf),('xgb',xgb),('gbdt',gbdt)],weights=[100,50,25,10])
pipe = Pipeline([
     ('s1',s1),
     ('s2',s2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8844245355336869
# MAE 0.1528929967171519

# %% [markdown]
# ## Stacking

# %%
s1 = ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,8,12,13])],remainder='passthrough')

estms = [
    ('rf',RandomForestRegressor(n_estimators=500,random_state=3,max_samples=0.7,max_features=0.5,max_depth=15)),
    ('xgb',XGBRegressor(n_estimators=100,learning_rate=0.5,max_depth=3)),
    ('et',ExtraTreesRegressor(n_estimators=100,random_state=3,bootstrap=True,max_samples=0.7,max_features=0.5,max_depth=15))    
]

s2 = StackingRegressor(estimators=estms,final_estimator=Ridge(alpha=100))
pipe = Pipeline([
     ('s1',s1),
     ('s2',s2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print('R2 Score', r2_score(y_test,y_pred))
print('MAE', mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8857435426042987
# MAE 0.1547496582386566
